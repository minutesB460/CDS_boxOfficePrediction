# %%
import json
from pathlib import Path

import pandas as pd
from utils import get_random_movie_id, get_metadata
from imdb_scraper import scrape_reviews
from mojo_scraper import scrape_worldwide_box_office

# ---------- CONFIG ----------
OUTPUT_PATH = Path("data/mini.jsonl")
TARGET = 30          # number of movies to scrape
MIN_VOTES = 1_000    # rating threshold

# create / truncate output file safely
OUTPUT_PATH.write_text("")

scraped = 0
while scraped < TARGET:
    movie_id = get_random_movie_id(min_votes=MIN_VOTES)
    try:
        # — reviews first (quick exit if none) —
        reviews = scrape_reviews(movie_id)
        if not reviews:
            continue

        # — box‑office (mandatory) —
        try:
            worldwide_gross = scrape_worldwide_box_office(movie_id)
        except Exception as e:
            print(f"⚠️  skipping {movie_id} (no box‑office): {e}")
            continue  # must have box‑office to keep

        # — metadata —
        meta_raw = get_metadata(movie_id)
        # replace pandas NaN/NaT with None so JSON is valid
        meta = {k: (None if pd.isna(v) else v) for k, v in meta_raw.items()}

        record = {
            **meta,
            "worldwide_box_office": worldwide_gross,
            "review_bodies": reviews,
        }

        with OUTPUT_PATH.open("a", encoding="utf-8") as f:
            f.write(json.dumps(record, ensure_ascii=False) + "\n")

        scraped += 1
        print(
            f"✅  {scraped}/{TARGET} | {movie_id} | {meta.get('primaryTitle')}"
        )

    except Exception as e:
        print(f"⚠️  skipping {movie_id}: {e}")
# Out:
# ⚠️  skipping tt2327119 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt6905692 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt15469890 (no box‑office): Worldwide gross not found
# ✅  1/30 | tt0265343 | Monsoon Wedding
# ✅  2/30 | tt9802890 | Christmas Jars
# ⚠️  skipping tt2973418 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt1032125 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt3487994 (no box‑office): Worldwide gross not found
# ✅  3/30 | tt0411118 | Anthony Zimmer
# ⚠️  skipping tt0808348 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0369036 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt9567818 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0082183 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0582962 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0400690 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt12867916 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0113939 (no box‑office): Worldwide gross not found
# ✅  4/30 | tt0034936 | Keeper of the Flame
# ⚠️  skipping tt8408814 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt9005728 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0016953 (no box‑office): Worldwide gross not found
# ✅  5/30 | tt0089079 | Eleni
# ✅  6/30 | tt28131427 | Black Dog
# ⚠️  skipping tt13825336 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt1785095 (no box‑office): Worldwide gross not found
# ✅  7/30 | tt0029322 | Nothing Sacred
# ⚠️  skipping tt5665452 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0057590 (no box‑office): Worldwide gross not found
# ✅  8/30 | tt2220408 | Vai que dá Certo
# ✅  9/30 | tt0085867 | The Lords of Discipline
# ⚠️  skipping tt0062728 (no box‑office): Worldwide gross not found
# ✅  10/30 | tt0855895 | Private Property
# ⚠️  skipping tt10418602 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0471990 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt1218336 (no box‑office): Worldwide gross not found
# ✅  11/30 | tt0111102 | Second Best
# ⚠️  skipping tt7786806 (no box‑office): Worldwide gross not found
# ✅  12/30 | tt0111333 | The Swan Princess
# ✅  13/30 | tt0101273 | The Adjuster
# ⚠️  skipping tt0162897 (no box‑office): Worldwide gross not found
# ✅  14/30 | tt1588337 | Of Gods and Men
# ✅  15/30 | tt0093744 | The New Adventures of Pippi Longstocking
# ⚠️  skipping tt0972555 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt4452688 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt11563912 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt15264532 (no box‑office): Worldwide gross not found
# ✅  16/30 | tt0396555 | Meet the Robinsons
# ✅  17/30 | tt0890886 | The Black Madonna
# ⚠️  skipping tt5618256 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0061796 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0076200 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt4594334 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt31863053 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0697741 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt6783056 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt0053455 (no box‑office): Worldwide gross not found
# ✅  18/30 | tt5636668 | Battle of Memories
# ✅  19/30 | tt15009428 | Argylle
# ⚠️  skipping tt0494199 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt5166198 (no box‑office): Worldwide gross not found
# ✅  20/30 | tt0119586 | Lucie Aubrac
# ✅  21/30 | tt4685806 | The Con is On
# ✅  22/30 | tt6041030 | Mad World
# ✅  23/30 | tt0361693 | Happy Endings
# ✅  24/30 | tt7295450 | Between Worlds
# ✅  25/30 | tt15354916 | Jawan
# ⚠️  skipping tt0855160 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt26965557 (no box‑office): Worldwide gross not found
# ✅  26/30 | tt4074502 | Dark Star: HR Gigers Welt
# ✅  27/30 | tt2365580 | Where'd You Go, Bernadette
# ⚠️  skipping tt9318588 (no box‑office): Worldwide gross not found
# ⚠️  skipping tt27041011 (no box‑office): Worldwide gross not found
# ✅  28/30 | tt0151137 | The Messenger: The Story of Joan of Arc
# ⚠️  skipping tt11646658 (no box‑office): Worldwide gross not found
# ✅  29/30 | tt7515456 | Mission of Honor
# ✅  30/30 | tt6069264 | Bitch
